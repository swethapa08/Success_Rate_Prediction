# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('M03.csv')

# %%
data
# Out:
#     Control Number  Confidence  Concentration  Responsiveness  Initiative  \
# 0          12-0492         4.0            4.0             4.0         5.0
# 1          12-0491         4.0            4.0             4.0         4.0
# 2          12-0490         5.0            4.0             5.0         5.0
# 3          12-0489         4.0            4.0             5.0         4.0
# 4          12-0488         5.0            4.0             5.0         5.0
# ..             ...         ...            ...             ...         ...
# 396        06-0463         5.0            3.0             4.0         5.0
# 397        06-0462         5.0            4.0             4.0         5.0
# 398        06-0461         5.0            4.0             5.0         5.0
# 399        06-0460         5.0            4.0             5.0         5.0
# 400        06-0429         3.0            3.0             3.0         3.0
#
#      Excitability  Hearing Sensitivity  Body Sensitivity   CR   IP  ...  CR.1  \
# ...

# %%
data.head(7)
# Out:
#   Control Number  Confidence  Concentration  Responsiveness  Initiative  \
# 0        12-0492         4.0            4.0             4.0         5.0
# 1        12-0491         4.0            4.0             4.0         4.0
# 2        12-0490         5.0            4.0             5.0         5.0
# 3        12-0489         4.0            4.0             5.0         4.0
# 4        12-0488         5.0            4.0             5.0         5.0
# 5        12-0487         4.0            4.0             5.0         5.0
# 6        12-0486         2.0            3.0             3.0         3.0
#
#    Excitability  Hearing Sensitivity  Body Sensitivity   CR   IP  ...  CR.1  \
# 0           4.0                  5.0               5.0  2.0  2.0  ...   5.0
# 1           5.0                  5.0               5.0  3.0  2.0  ...   5.0
# 2           5.0                  5.0               5.0  3.0  2.0  ...   5.0
# 3           4.0                  5.0               5.0  2.0  2.0  ...   5.0
# ...

# %%
data.shape
# Out:
# (401, 22)

# %%
data.dtypes
# Out:
# Control Number          object
# Confidence             float64
# Concentration          float64
# Responsiveness         float64
# Initiative             float64
# Excitability           float64
# Hearing Sensitivity    float64
# Body Sensitivity       float64
# CR                     float64
# IP                     float64
# PP                     float64
# Total Score            float64
# CR.1                   float64
# MP                     float64
# PP.1                   float64
# IP.1                   float64
# HG                     float64
# H1                     float64
# H2                     float64
# ACT                    float64
# Total Score.1          float64
# BehElim                  int64
# dtype: object

# %%
data.isna().sum()
# Out:
# Control Number          0
# Confidence              5
# Concentration           5
# Responsiveness          5
# Initiative              5
# Excitability            5
# Hearing Sensitivity     5
# Body Sensitivity        5
# CR                      6
# IP                      5
# PP                      5
# Total Score             5
# CR.1                    9
# MP                      9
# PP.1                    9
# IP.1                    9
# HG                      9
# H1                      9
# H2                      9
# ACT                    10
# Total Score.1           9
# BehElim                 0
# dtype: int64

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.dropna()
# Out:
#     Control Number  Confidence  Concentration  Responsiveness  Initiative  \
# 0          12-0492         4.0            4.0             4.0         5.0
# 1          12-0491         4.0            4.0             4.0         4.0
# 2          12-0490         5.0            4.0             5.0         5.0
# 3          12-0489         4.0            4.0             5.0         4.0
# 4          12-0488         5.0            4.0             5.0         5.0
# ..             ...         ...            ...             ...         ...
# 396        06-0463         5.0            3.0             4.0         5.0
# 397        06-0462         5.0            4.0             4.0         5.0
# 398        06-0461         5.0            4.0             5.0         5.0
# 399        06-0460         5.0            4.0             5.0         5.0
# 400        06-0429         3.0            3.0             3.0         3.0
#
#      Excitability  Hearing Sensitivity  Body Sensitivity   CR   IP  ...  CR.1  \
# ...

# %%
data.describe()
# Out:
#        Confidence  Concentration  Responsiveness  Initiative  Excitability  \
# count  396.000000     396.000000      396.000000  396.000000    396.000000
# mean     3.890152       3.698232        4.068182    4.171717      4.646465
# std      0.895801       0.732066        0.852634    0.927530      0.690817
# min      1.000000       0.000000        1.000000    1.000000      1.000000
# 25%      3.000000       3.000000        4.000000    4.000000      4.000000
# 50%      4.000000       4.000000        4.000000    4.000000      5.000000
# 75%      5.000000       4.000000        5.000000    5.000000      5.000000
# max      5.000000       5.000000        5.000000    5.000000      5.000000
#
#        Hearing Sensitivity  Body Sensitivity          CR          IP  \
# count           396.000000        396.000000  395.000000  396.000000
# mean              4.886364          4.936869    2.622785    2.010101
# std               0.426604          0.307796    0.646731    0.850852
# ...

# %%
plt.subplots(figsize=(17,7))
sns.countplot(x='Total Score', hue='Concentration', data=data, palette='colorblind')
# Out:
# <Axes: xlabel='Total Score', ylabel='count'>

# %%
for c in data.columns:
    if data[c].dtype == object:
        print(str(c) +' : '+str(data[c].unique()))
        print(data[c].value_counts())
        print('____________________________________________________________________________')
# Out:
# Control Number : ['12-0492' '12-0491' '12-0490' '12-0489' '12-0488' '12-0487' '12-0486'
#  '12-0475' '12-0474' '12-0473' '12-0472' '12-0471' '12-0470' '12-0469'
#  '12-0468' '12-0467' '12-0450' '12-0449' '12-0448' '12-0447' '12-0027'
#  '12-0026' '12-0025' '12-0024' '12-0023' '12-0022' '12-0021' '12-0020'
#  '12-0016' '12-0015' '12-0014' '12-0013' '12-0012' '12-0011' '12-0010'
#  '12-0009' '11-1364' '11-1363' '11-1362' '11-1361' '11-1360' '11-1359'
#  '11-1358' '11-0947' '11-0946' '11-0945' '11-0944' '11-0943' '11-0942'
#  '11-0863' '11-0862' '11-0861' '11-0860' '11-0859' '11-0512' '11-0511'
#  '11-0510' '11-0509' '11-0506' '11-0504' '11-0503' '11-0500' '11-0499'
#  '11-0498' '11-0497' '11-0495' '11-0486' '11-0485' '11-0484' '11-0483'
#  '11-0482' '11-0067' '11-0066' '11-0065' '11-0064' '11-0063' '11-0062'
#  '11-0061' '11-0060' '10-1825' '10-1824' '10-1823' '10-1822' '10-1820'
#  '10-1819' '10-1791' '10-1790' '10-1789' '10-1788' '10-1787' '10-1782'
# ...

# %%
X=data.iloc[:,1:data.shape[1]].values
Y=data.iloc[:,0].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
forest=RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)
data = RandomForestClassifier()
forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
forest.score(X_train, Y_train)
# Out:
# 0.9733333333333334

# %%
y_pred = forest.predict(X_test)

# %%
new_data=[[7-1111, 5.0, 3.5, 4.0, 5.0, 3.0, 5.0, 5.0, 2.0, 3.0, 4.0, 5.5, 4.0, 3.0, 4.0, 5.0, 3.0, 4.0, 5.0, 75, 0]]
prediction = forest.predict(new_data)

# %%
print("Predicted Success Rate: ", prediction)
# Out:
# Predicted Success Rate:  ['06-0774']
